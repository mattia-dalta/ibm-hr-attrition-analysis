# %% [markdown]
# ## IBM HR Analytics Employee Attrition & Performance

# %%
import pandas as pd

# %%
# URL to the raw CSV file hosted on GitHub
url = "https://raw.githubusercontent.com/mattia-dalta/ibm-hr-attrition-analysis/refs/heads/main/WA_Fn-UseC_-HR-Employee-Attrition.csv"

# Read the dataset
df = pd.read_csv(url)

# Display the first 5 rows
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.dtypes   #data types are correct
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...

# %%
df['EmployeeCount'].value_counts()
# Out:
# EmployeeCount
# 1    1470
# Name: count, dtype: int64

# %%
df['StandardHours'].value_counts()
# Out:
# StandardHours
# 80    1470
# Name: count, dtype: int64

# %%
df['Over18'].value_counts()
# Out:
# Over18
# Y    1470
# Name: count, dtype: int64

# %%
df['EmployeeNumber'].is_unique
# Out:
# True

# %%
# Basic stats for the salary-related columns
df[['DailyRate', 'HourlyRate', 'MonthlyRate', 'MonthlyIncome']].describe()
# Out:
#          DailyRate   HourlyRate   MonthlyRate  MonthlyIncome
# count  1470.000000  1470.000000   1470.000000    1470.000000
# mean    802.485714    65.891156  14313.103401    6502.931293
# std     403.509100    20.329428   7117.786044    4707.956783
# min     102.000000    30.000000   2094.000000    1009.000000
# 25%     465.000000    48.000000   8047.000000    2911.000000
# 50%     802.000000    66.000000  14235.500000    4919.000000
# 75%    1157.000000    83.750000  20461.500000    8379.000000
# max    1499.000000   100.000000  26999.000000   19999.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pairplot per osservare visivamente la relazione
sns.pairplot(df[['DailyRate', 'HourlyRate', 'MonthlyRate', 'MonthlyIncome']])
plt.suptitle("Salary Field Relationships", y=1.02)
plt.show()

# %%
df[['DailyRate', 'HourlyRate', 'MonthlyRate', 'MonthlyIncome']].corr()
# Out:
#                DailyRate  HourlyRate  MonthlyRate  MonthlyIncome
# DailyRate       1.000000    0.023381    -0.032182       0.007707
# HourlyRate      0.023381    1.000000    -0.015297      -0.015794
# MonthlyRate    -0.032182   -0.015297     1.000000       0.034814
# MonthlyIncome   0.007707   -0.015794     0.034814       1.000000

# %%
# Convert Attrition to numeric
df['Attrition_num'] = df['Attrition'].map({'Yes': 1, 'No': 0})

# Correlation with target
df[['DailyRate', 'HourlyRate', 'MonthlyRate', 'MonthlyIncome', 'Attrition_num']].corr()['Attrition_num']
# Out:
# DailyRate       -0.056652
# HourlyRate      -0.006846
# MonthlyRate      0.015170
# MonthlyIncome   -0.159840
# Attrition_num    1.000000
# Name: Attrition_num, dtype: float64

# %%
df.drop(columns='Attrition_num', inplace=True)

# %%
# Drop columns that are constant, redundant, or not useful for analysis
columns_to_drop = [
    'EmployeeCount',      # Always 1, no analytical value
    'StandardHours',      # Always 80, no variability
    'Over18',             # Always 'Y', not informative
    'EmployeeNumber',     # Unique ID, not useful for analysis
    'DailyRate',          # Artificial salary figure
    'HourlyRate',         # Artificial salary figure
    'MonthlyRate'         # Artificial salary figure
]

df_cleaned = df.drop(columns=columns_to_drop)

# %%
# Rename columns to make them more readable and presentation-friendly
columns_to_rename = {
    'Attrition': 'LeftCompany',
    'BusinessTravel': 'TravelFreq',
    'EnvironmentSatisfaction': 'EnvSatisfaction',
    'JobSatisfaction': 'JobSatisfaction',
    'WorkLifeBalance': 'WorkLife',
    'RelationshipSatisfaction': 'RelSatisfaction',
    'OverTime': 'Overtime',
    'YearsAtCompany': 'YearsInCompany',
    'YearsSinceLastPromotion': 'YearsSincePromo',
    'YearsWithCurrManager': 'YearsWithManager'
}

df_cleaned = df_cleaned.rename(columns=columns_to_rename)

# %%
# Show the number of remaining columns after cleaning
num_columns = df_cleaned.shape[1]
print(f"The dataset now contains {num_columns} columns after cleaning.")
# Out:
# The dataset now contains 28 columns after cleaning.

# %% [markdown]
# ### Feature Selection & Column Cleaning
#
# As part of the data preparation process, several columns were removed from the original dataset.
# This step was necessary to simplify the analysis and eliminate variables that added no analytical valuevisualization.

# %% [markdown]
# ### Columns deleted and why:
#
# - **EmployeeCount**: Constant value (always 1), adds no information.
# - **StandardHours**: Constant value (always 80), not useful.
# - **Over18**: Constant value ('Y'), irrelevant for attrition analysis.
# - **EmployeeNumber**: Unique identifier, not informative for analysis.
# - **DailyRate**, **HourlyRate**, **MonthlyRate**: Artificial and uncorrelated salary components. We kept only `MonthlyIncome`, which is the most interpretable and relevant for business insights.
#
# These columns were either redundant, constant, or not meaningful in the context of employee attrition.
# By dropping them, we improved the focus and readability of our dataset for downstream Tableau visualization.

# %%
# Check for missing values in the cleaned dataset
missing_counts = df_cleaned.isnull().sum()

# Show only columns with at least 1 missing value
missing_counts[missing_counts > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# This confirms that there are no missing values in the dataset, and no imputation or filtering is necessary.
# The dataset is now fully clean and ready to be exported to Tableau.

# %%
remaining_columns = df_cleaned.columns.tolist()
print("Remaining variables in the cleaned dataset:")
for col in remaining_columns:
    print(f"- {col}")
# Out:
# Remaining variables in the cleaned dataset:
# - Age
# - LeftCompany
# - TravelFreq
# - Department
# - DistanceFromHome
# - Education
# - EducationField
# - EnvSatisfaction
# - Gender
# - JobInvolvement
# - JobLevel
# - JobRole
# - JobSatisfaction
# - MaritalStatus
# - MonthlyIncome
# - NumCompaniesWorked
# - Overtime
# - PercentSalaryHike
# - PerformanceRating
# - RelSatisfaction
# - StockOptionLevel
# - TotalWorkingYears
# - TrainingTimesLastYear
# - WorkLife
# - YearsInCompany
# - YearsInCurrentRole
# - YearsSincePromo
# - YearsWithManager

# %%
# Export the cleaned DataFrame to a CSV file
df_cleaned.to_csv("HR_cleaned_for_tableau.csv", index=False)
